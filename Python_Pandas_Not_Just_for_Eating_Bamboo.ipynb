# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('vgsales.csv')

# %%
data.head()
# Out:
#    Rank                      Name Platform    Year         Genre Publisher  \
# 0     1                Wii Sports      Wii  2006.0        Sports  Nintendo
# 1     2         Super Mario Bros.      NES  1985.0      Platform  Nintendo
# 2     3            Mario Kart Wii      Wii  2008.0        Racing  Nintendo
# 3     4         Wii Sports Resort      Wii  2009.0        Sports  Nintendo
# 4     5  Pokemon Red/Pokemon Blue       GB  1996.0  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0     41.49     29.02      3.77         8.46         82.74
# 1     29.08      3.58      6.81         0.77         40.24
# 2     15.85     12.88      3.79         3.31         35.82
# 3     15.75     11.01      3.28         2.96         33.00
# 4     11.27      8.89     10.22         1.00         31.37

# %% [markdown]
# filtered_df = data[data['Global_sales'] > 50]
# print(filtered_df.head())

# %%
# Print summary statistics
print(data.describe())
# Out:
#                Rank          Year      NA_Sales      EU_Sales      JP_Sales  \
# count  16598.000000  16327.000000  16598.000000  16598.000000  16598.000000
# mean    8300.605254   2006.406443      0.264667      0.146652      0.077782
# std     4791.853933      5.828981      0.816683      0.505351      0.309291
# min        1.000000   1980.000000      0.000000      0.000000      0.000000
# 25%     4151.250000   2003.000000      0.000000      0.000000      0.000000
# 50%     8300.500000   2007.000000      0.080000      0.020000      0.000000
# 75%    12449.750000   2010.000000      0.240000      0.110000      0.040000
# max    16600.000000   2020.000000     41.490000     29.020000     10.220000
#
#         Other_Sales  Global_Sales
# count  16598.000000  16598.000000
# mean       0.048063      0.537441
# std        0.188588      1.555028
# min        0.000000      0.010000
# 25%        0.000000      0.060000
# 50%        0.010000      0.170000
# 75%        0.040000      0.470000
# ...

# %%
data.dtypes
# Out:
# Rank              int64
# Name             object
# Platform         object
# Year            float64
# Genre            object
# Publisher        object
# NA_Sales        float64
# EU_Sales        float64
# JP_Sales        float64
# Other_Sales     float64
# Global_Sales    float64
# dtype: object

# %%
filtered_df = data[data['Global_Sales'] > 10]
print(filtered_df.head())
# Out:
#    Rank                      Name Platform    Year         Genre Publisher  \
# 0     1                Wii Sports      Wii  2006.0        Sports  Nintendo
# 1     2         Super Mario Bros.      NES  1985.0      Platform  Nintendo
# 2     3            Mario Kart Wii      Wii  2008.0        Racing  Nintendo
# 3     4         Wii Sports Resort      Wii  2009.0        Sports  Nintendo
# 4     5  Pokemon Red/Pokemon Blue       GB  1996.0  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0     41.49     29.02      3.77         8.46         82.74
# 1     29.08      3.58      6.81         0.77         40.24
# 2     15.85     12.88      3.79         3.31         35.82
# 3     15.75     11.01      3.28         2.96         33.00
# 4     11.27      8.89     10.22         1.00         31.37

# %%
# Detect missing values
print(data.isna().sum())
# Out:
# Rank              0
# Name              0
# Platform          0
# Year            271
# Genre             0
# Publisher        58
# NA_Sales          0
# EU_Sales          0
# JP_Sales          0
# Other_Sales       0
# Global_Sales      0
# dtype: int64

# %%
# Fill missing values with mean of each column
data = data.fillna(data.mean())
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_4360\4287748486.py:2: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   data = data.fillna(data.mean())

# %%
# Create scatter plot with Seaborn
sns.set_palette('husl')  # set color palette
plt.figure(figsize=(8, 6))  # set size of chart
sns.scatterplot(x='Rank', y='Year', hue='Publisher', data=data)
plt.title('Scatter Plot of Data')
plt.xlabel('X-axis label')
plt.ylabel('Y-axis label')
plt.show()

# %%
# Print correlation matrix
print(data.corr())
# Out:
#                   Rank      Year  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# Rank          1.000000  0.178814 -0.401362 -0.379123 -0.267785    -0.332986
# Year          0.178814  1.000000 -0.091402  0.006014 -0.169316     0.041058
# NA_Sales     -0.401362 -0.091402  1.000000  0.767727  0.449787     0.634737
# EU_Sales     -0.379123  0.006014  0.767727  1.000000  0.435584     0.726385
# JP_Sales     -0.267785 -0.169316  0.449787  0.435584  1.000000     0.290186
# Other_Sales  -0.332986  0.041058  0.634737  0.726385  0.290186     1.000000
# Global_Sales -0.427407 -0.074735  0.941047  0.902836  0.611816     0.748331
#
#               Global_Sales
# Rank             -0.427407
# Year             -0.074735
# NA_Sales          0.941047
# EU_Sales          0.902836
# JP_Sales          0.611816
# Other_Sales       0.748331
# Global_Sales      1.000000

# %%
# Create box plot of column1
sns.boxplot(x='Rank', data=data)
plt.title('Box Plot of Rank')
plt.show()

# %%
# Create histogram of column2
sns.histplot(x='Global_Sales', data=data, bins=20)
plt.title('Histogram of Global_Sales ')
plt.show()

# %%
# Create scatter plot of column1 vs. column2
sns.scatterplot(x='Year', y='Rank', data=data)
plt.title('Scatter Plot of Year vs. Rank')
plt.show()

# %%
grouped_df = df.groupby('Year')['Global_Sales'].mean()
print(grouped_df)
# Out:
# Year
# 1980.0    1.264444
# 1981.0    0.777609
# 1982.0    0.801667
# 1983.0    0.987647
# 1984.0    3.597143
# 1985.0    3.852857
# 1986.0    1.765238
# 1987.0    1.358750
# 1988.0    3.148000
# 1989.0    4.320588
# 1990.0    3.086875
# 1991.0    0.786098
# 1992.0    1.771163
# 1993.0    0.766333
# 1994.0    0.654298
# 1995.0    0.402329
# 1996.0    0.757224
# 1997.0    0.695433
# 1998.0    0.676702
# 1999.0    0.743402
# 2000.0    0.577536
# 2001.0    0.687697
# 2002.0    0.477105
# 2003.0    0.461742
# 2004.0    0.549554
# 2005.0    0.488778
# 2006.0    0.516905
# 2007.0    0.508428
# 2008.0    0.475420
# 2009.0    0.466317
# 2010.0    0.476926
# 2011.0    0.453020
# 2012.0    0.553333
# 2013.0    0.674194
# 2014.0    0.579124
# 2015.0    0.430684
# 2016.0    0.206192
# 2017.0    0.016667
# 2020.0    0.290000
# Name: Global_Sales, dtype: float64

# %%
# Calculate the total revenue for each Platform
revenue_per_platform = data.groupby('Platform')['Global_Sales'].sum()
print(revenue_per_platform)
# Out:
# Platform
# 2600      97.08
# 3DO        0.10
# 3DS      247.46
# DC        15.97
# DS       822.49
# GB       255.45
# GBA      318.50
# GC       199.36
# GEN       28.36
# GG         0.04
# N64      218.88
# NES      251.07
# NG         1.44
# PC       258.82
# PCFX       0.03
# PS       730.66
# PS2     1255.64
# PS3      957.84
# PS4      278.10
# PSP      296.28
# PSV       61.93
# SAT       33.59
# SCD        1.87
# SNES     200.05
# TG16       0.16
# WS         1.42
# Wii      926.71
# WiiU      81.86
# X360     979.96
# XB       258.26
# XOne     141.06
# Name: Global_Sales, dtype: float64

# %%
# Filter the data to show global sales more then 50
filtered_data = data[data['Global_Sales'] > 50]

# %%
print(filtered_data)
# Out:
#    Rank        Name Platform    Year   Genre Publisher  NA_Sales  EU_Sales  \
# 0     1  Wii Sports      Wii  2006.0  Sports  Nintendo     41.49     29.02
#
#    JP_Sales  Other_Sales  Global_Sales
# 0      3.77         8.46         82.74
